# %%
import numpy as np
from sklearn import datasets
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense
from tensorflow.keras import optimizers
from tensorflow.keras import losses
from tensorflow.keras import metrics
np.random.seed(123)
tf.set_random_seed(123)



class MLP(Model):
    #多層パーセプトロン
    def __init__(self, hidden_dim, output_dim):
        super().__init__()
        self.l1 = Dense(hidden_dim, activation = "sigmoid")
        self.l2 = Dense(output_dim, activation = "sigmoid")
        
    def call(self, x):
        h = self.l1(x)
        y = self.l2(h)
        return y



#データの準備
N = 300
x, t = datasets.make_moons(N, noise = 0.3)
t = t.reshape(N, 1)

x_train, x_test, t_train, t_test = \
    train_test_split(x, t, test_size = 0.2)



#モデルの構築
model = MLP(3, 1)



#モデルの学習
criterion = losses.BinaryCrossentropy()
optimizer = optimizers.SGD(learning_rate = 0.1)

def compute_loss(t, y):
    return criterion(t, y)

def train_step(x, t):
    with tf.GradientTape() as tape:
        preds = model(x)
        loss = compute_loss(t, preds)
    grads = tape.gradient(loss, model.trainable_variables)
    optimizer.apply_gradients(zip(grads, model.trainable_variables))
    return loss


epochs = 100
batch_size = 10
n_batches = x_train.shape[0] // batch_size

for epoch in range(epochs):
    train_loss = 0.
    x_, t_ = shuffle(x_train, t_train)
    
    for batch in range(n_batches):
        start = batch * batch_size
        end = start * batch_size
        loss = train_step(x_[start:end], t_[start:end])
        train_loss += loss
        
    print("epoch: ", epoch + 1, "loss: ", train_loss)

    
    
    
#モデルの評価
test_loss = metrics.Mean()
test_acc = metrics.BinaryAccuracy()

def test_step(x, t):
    preds = model(x)
    loss = compute_loss(t, preds)
    test_loss(loss)
    test_acc(t, preds)
    return preds

test_step(x_test, t_test)
print("test_loss: ", test_loss.result())
print("test_acc: {.3f}", test_acc.result())
# Out:
# epoch:  1 loss:  Tensor("add_9769:0", shape=(), dtype=float64)
# epoch:  2 loss:  Tensor("add_9817:0", shape=(), dtype=float64)
# epoch:  3 loss:  Tensor("add_9865:0", shape=(), dtype=float64)
# epoch:  4 loss:  Tensor("add_9913:0", shape=(), dtype=float64)
# epoch:  5 loss:  Tensor("add_9961:0", shape=(), dtype=float64)
# epoch:  6 loss:  Tensor("add_10009:0", shape=(), dtype=float64)
# epoch:  7 loss:  Tensor("add_10057:0", shape=(), dtype=float64)
# epoch:  8 loss:  Tensor("add_10105:0", shape=(), dtype=float64)
# epoch:  9 loss:  Tensor("add_10153:0", shape=(), dtype=float64)
# epoch:  10 loss:  Tensor("add_10201:0", shape=(), dtype=float64)
# epoch:  11 loss:  Tensor("add_10249:0", shape=(), dtype=float64)
# epoch:  12 loss:  Tensor("add_10297:0", shape=(), dtype=float64)
# epoch:  13 loss:  Tensor("add_10345:0", shape=(), dtype=float64)
# epoch:  14 loss:  Tensor("add_10393:0", shape=(), dtype=float64)
# epoch:  15 loss:  Tensor("add_10441:0", shape=(), dtype=float64)
# epoch:  16 loss:  Tensor("add_10489:0", shape=(), dtype=float64)
# epoch:  17 loss:  Tensor("add_10537:0", shape=(), dtype=float64)
# epoch:  18 loss:  Tensor("add_10585:0", shape=(), dtype=float64)
# epoch:  19 loss:  Tensor("add_10633:0", shape=(), dtype=float64)
# epoch:  20 loss:  Tensor("add_10681:0", shape=(), dtype=float64)
# epoch:  21 loss:  Tensor("add_10729:0", shape=(), dtype=float64)
# epoch:  22 loss:  Tensor("add_10777:0", shape=(), dtype=float64)
# epoch:  23 loss:  Tensor("add_10825:0", shape=(), dtype=float64)
# epoch:  24 loss:  Tensor("add_10873:0", shape=(), dtype=float64)
# epoch:  25 loss:  Tensor("add_10921:0", shape=(), dtype=float64)
# epoch:  26 loss:  Tensor("add_10969:0", shape=(), dtype=float64)
# epoch:  27 loss:  Tensor("add_11017:0", shape=(), dtype=float64)
# epoch:  28 loss:  Tensor("add_11065:0", shape=(), dtype=float64)
# epoch:  29 loss:  Tensor("add_11113:0", shape=(), dtype=float64)
# epoch:  30 loss:  Tensor("add_11161:0", shape=(), dtype=float64)
# epoch:  31 loss:  Tensor("add_11209:0", shape=(), dtype=float64)
# epoch:  32 loss:  Tensor("add_11257:0", shape=(), dtype=float64)
# epoch:  33 loss:  Tensor("add_11305:0", shape=(), dtype=float64)
# epoch:  34 loss:  Tensor("add_11353:0", shape=(), dtype=float64)
# epoch:  35 loss:  Tensor("add_11401:0", shape=(), dtype=float64)
# epoch:  36 loss:  Tensor("add_11449:0", shape=(), dtype=float64)
# epoch:  37 loss:  Tensor("add_11497:0", shape=(), dtype=float64)
# epoch:  38 loss:  Tensor("add_11545:0", shape=(), dtype=float64)
# epoch:  39 loss:  Tensor("add_11593:0", shape=(), dtype=float64)
# epoch:  40 loss:  Tensor("add_11641:0", shape=(), dtype=float64)
# epoch:  41 loss:  Tensor("add_11689:0", shape=(), dtype=float64)
# epoch:  42 loss:  Tensor("add_11737:0", shape=(), dtype=float64)
# epoch:  43 loss:  Tensor("add_11785:0", shape=(), dtype=float64)
# epoch:  44 loss:  Tensor("add_11833:0", shape=(), dtype=float64)
# epoch:  45 loss:  Tensor("add_11881:0", shape=(), dtype=float64)
# epoch:  46 loss:  Tensor("add_11929:0", shape=(), dtype=float64)
# epoch:  47 loss:  Tensor("add_11977:0", shape=(), dtype=float64)
# epoch:  48 loss:  Tensor("add_12025:0", shape=(), dtype=float64)
# epoch:  49 loss:  Tensor("add_12073:0", shape=(), dtype=float64)
# epoch:  50 loss:  Tensor("add_12121:0", shape=(), dtype=float64)
# epoch:  51 loss:  Tensor("add_12169:0", shape=(), dtype=float64)
# epoch:  52 loss:  Tensor("add_12217:0", shape=(), dtype=float64)
# epoch:  53 loss:  Tensor("add_12265:0", shape=(), dtype=float64)
# epoch:  54 loss:  Tensor("add_12313:0", shape=(), dtype=float64)
# epoch:  55 loss:  Tensor("add_12361:0", shape=(), dtype=float64)
# epoch:  56 loss:  Tensor("add_12409:0", shape=(), dtype=float64)
# epoch:  57 loss:  Tensor("add_12457:0", shape=(), dtype=float64)
# epoch:  58 loss:  Tensor("add_12505:0", shape=(), dtype=float64)
# epoch:  59 loss:  Tensor("add_12553:0", shape=(), dtype=float64)
# epoch:  60 loss:  Tensor("add_12601:0", shape=(), dtype=float64)
# epoch:  61 loss:  Tensor("add_12649:0", shape=(), dtype=float64)
# epoch:  62 loss:  Tensor("add_12697:0", shape=(), dtype=float64)
# epoch:  63 loss:  Tensor("add_12745:0", shape=(), dtype=float64)
# epoch:  64 loss:  Tensor("add_12793:0", shape=(), dtype=float64)
# epoch:  65 loss:  Tensor("add_12841:0", shape=(), dtype=float64)
# epoch:  66 loss:  Tensor("add_12889:0", shape=(), dtype=float64)
# epoch:  67 loss:  Tensor("add_12937:0", shape=(), dtype=float64)
# epoch:  68 loss:  Tensor("add_12985:0", shape=(), dtype=float64)
# epoch:  69 loss:  Tensor("add_13033:0", shape=(), dtype=float64)
# epoch:  70 loss:  Tensor("add_13081:0", shape=(), dtype=float64)
# epoch:  71 loss:  Tensor("add_13129:0", shape=(), dtype=float64)
# epoch:  72 loss:  Tensor("add_13177:0", shape=(), dtype=float64)
# epoch:  73 loss:  Tensor("add_13225:0", shape=(), dtype=float64)
# epoch:  74 loss:  Tensor("add_13273:0", shape=(), dtype=float64)
# epoch:  75 loss:  Tensor("add_13321:0", shape=(), dtype=float64)
# epoch:  76 loss:  Tensor("add_13369:0", shape=(), dtype=float64)
# epoch:  77 loss:  Tensor("add_13417:0", shape=(), dtype=float64)
# epoch:  78 loss:  Tensor("add_13465:0", shape=(), dtype=float64)
# epoch:  79 loss:  Tensor("add_13513:0", shape=(), dtype=float64)
# epoch:  80 loss:  Tensor("add_13561:0", shape=(), dtype=float64)
# epoch:  81 loss:  Tensor("add_13609:0", shape=(), dtype=float64)
# epoch:  82 loss:  Tensor("add_13657:0", shape=(), dtype=float64)
# epoch:  83 loss:  Tensor("add_13705:0", shape=(), dtype=float64)
# epoch:  84 loss:  Tensor("add_13753:0", shape=(), dtype=float64)
# epoch:  85 loss:  Tensor("add_13801:0", shape=(), dtype=float64)
# epoch:  86 loss:  Tensor("add_13849:0", shape=(), dtype=float64)
# epoch:  87 loss:  Tensor("add_13897:0", shape=(), dtype=float64)
# epoch:  88 loss:  Tensor("add_13945:0", shape=(), dtype=float64)
# epoch:  89 loss:  Tensor("add_13993:0", shape=(), dtype=float64)
# epoch:  90 loss:  Tensor("add_14041:0", shape=(), dtype=float64)
# epoch:  91 loss:  Tensor("add_14089:0", shape=(), dtype=float64)
# epoch:  92 loss:  Tensor("add_14137:0", shape=(), dtype=float64)
# epoch:  93 loss:  Tensor("add_14185:0", shape=(), dtype=float64)
# epoch:  94 loss:  Tensor("add_14233:0", shape=(), dtype=float64)
# epoch:  95 loss:  Tensor("add_14281:0", shape=(), dtype=float64)
# epoch:  96 loss:  Tensor("add_14329:0", shape=(), dtype=float64)
# epoch:  97 loss:  Tensor("add_14377:0", shape=(), dtype=float64)
# epoch:  98 loss:  Tensor("add_14425:0", shape=(), dtype=float64)
# epoch:  99 loss:  Tensor("add_14473:0", shape=(), dtype=float64)
# epoch:  100 loss:  Tensor("add_14521:0", shape=(), dtype=float64)
# test_loss:  Tensor("Identity_6:0", shape=(), dtype=float32)
# test_acc: {.3f} Tensor("Identity_7:0", shape=(), dtype=float32)

# %%
x = tf.constant(1, name="x")
y = tf.constant(2, name="y")

add_op = tf.add(x, y)

with tf.Session() as sess:
    print(sess.run(add_op))
# Out:
# 3

# %%
z = tf.constant(1, name = "z")
print(z.eval())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-29-fd44028c6b2c> in <module>
#       1 z = tf.constant(1, name = "z")
# ----> 2 print(z.eval())
#
# c:\users\robotics\anaconda3\envs\tensorflow\lib\site-packages\tensorflow_core\python\framework\ops.py in eval(self, feed_dict, session)
#     796
#     797     """
# --> 798     return _eval_using_default_session(self, feed_dict, self.graph, session)
#     799
#     800   def experimental_ref(self):
#
# c:\users\robotics\anaconda3\envs\tensorflow\lib\site-packages\tensorflow_core\python\framework\ops.py in _eval_using_default_session(tensors, feed_dict, graph, session)
#    5391     session = get_default_session()
#    5392     if session is None:
# -> 5393       raise ValueError("Cannot evaluate tensor using `eval()`: No default "
#    5394                        "session is registered. Use `with "
#    5395                        "sess.as_default()` or pass an explicit session to "
#
# ValueError: Cannot evaluate tensor using `eval()`: No default session is registered. Use `with sess.as_default()` or pass an explicit session to `eval(session=sess)`
